# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    891
# Name: count, dtype: int64

# %%
(df.isna().mean() * 100).sort_values(ascending= False)
# Out:
# Cabin          77.104377
# Age            19.865320
# Embarked        0.224467
# PassengerId     0.000000
# Name            0.000000
# Pclass          0.000000
# Survived        0.000000
# Sex             0.000000
# Parch           0.000000
# SibSp           0.000000
# Fare            0.000000
# Ticket          0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df['Cabin'].dropna().head(20)
# Out:
# 1             C85
# 3            C123
# 6             E46
# 10             G6
# 11           C103
# 21            D56
# 23             A6
# 27    C23 C25 C27
# 31            B78
# 52            D33
# 54            B30
# 55            C52
# 61            B28
# 62            C83
# 66            F33
# 75          F G73
# 88    C23 C25 C27
# 92            E31
# 96             A5
# 97        D10 D12
# Name: Cabin, dtype: str

# %%
df.loc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
sns.histplot(df['Age'],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df_check = df.copy()

# %%
df_check['Age'] = df_check['Age'].fillna(df['Age'].mean())

# %%
sns.histplot(df_check['Age'],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['Sex'], y=df['Age'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
sns.boxplot(data=df,x='Pclass',y='Age',hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(data=df,y='Age',x='SibSp')
# Out:
# <Axes: xlabel='SibSp', ylabel='Age'>

# %%
filling = df_check.groupby(['Sex', 'Pclass'])['Age'].median()

# %%
filling
# Out:
# Sex     Pclass
# female  1         32.500000
#         2         28.500000
#         3         28.000000
# male    1         36.000000
#         2         29.699118
#         3         29.699118
# Name: Age, dtype: float64

# %%
df['Age'] = df['Age'].fillna(df.groupby(['Pclass','Sex'])['Age'].transform('median'))

# %%
sns.histplot(df_check['Age'],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df_check['Cabin'] = df_check['Cabin'].fillna('None')

# %%
df_check['Cabin_Status'] = np.where(df_check['Cabin'] != "None", "Yes","No")

# %%
sns.countplot(data=df_check,y='Pclass',hue='Cabin_Status')
# Out:
# <Axes: xlabel='count', ylabel='Pclass'>

# %%
df_check[df_check['Cabin'] != "None"].head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
# 23           24         1       1
# 27           28         0       1
# 31           32         1       1
# 52           53         1       1
# 54           55         0       1
# 55           56         1       1
# 61           62         1       1
# 62           63         0       1
# 66           67         1       2
# 75           76         0       3
# 88           89         1       1
# 92           93         0       1
# 96           97         0       1
# 97           98         1       1
#
#                                                  Name     Sex        Age  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# ...

# %%
df['Deck'] = np.where(df['Cabin'].isna(),'Unknown',df['Cabin'].str[0])

# %%
df[df['Deck'] != "Unknown"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.countplot(data=df,y='Pclass',hue='Deck')
# Out:
# <Axes: xlabel='count', ylabel='Pclass'>

# %%
sns.countplot(y=df['Deck'],hue=df['Survived'])
# Out:
# <Axes: xlabel='count', ylabel='Deck'>

# %%
df.groupby(['Deck'])['Survived'].mean()
# Out:
# Deck
# A          0.466667
# B          0.744681
# C          0.593220
# D          0.757576
# E          0.750000
# F          0.615385
# G          0.500000
# T          0.000000
# Unknown    0.299854
# Name: Survived, dtype: float64

# %%
df.drop(columns='Cabin',inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# Deck           0
# dtype: int64

# %%
df[df['Embarked'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Embarked Deck
# 61   female  38.0      0      0  113572  80.0      NaN    B
# 829  female  62.0      0      0  113572  80.0      NaN    B

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  25.0      0
# ...

# %%
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Deck           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked     Deck
# 0      0         A/5 21171   7.2500        S  Unknown
# 1      0          PC 17599  71.2833        C        C
# 2      0  STON/O2. 3101282   7.9250        S  Unknown
# 3      0            113803  53.1000        S        C
# ...

# %%
sns.histplot(x=df['Fare'],bins=20,kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.boxplot(hue=df['Pclass'],y=df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.histplot(df['SibSp'],bins=20,kde=True)
# Out:
# <Axes: xlabel='SibSp', ylabel='Count'>

# %%
sns.boxplot(df['SibSp'])
# Out:
# <Axes: ylabel='SibSp'>

# %%
sns.boxplot(df['Parch'])
# Out:
# <Axes: ylabel='Parch'>

# %%
sns.histplot(df['Parch'],bins=20,kde=True)
# Out:
# <Axes: xlabel='Parch', ylabel='Count'>

# %%
sns.countplot(x=df['Sex'],hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
sns.countplot(x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x=df['Pclass'],hue=df['Survived'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
sns.catplot(x=df['Pclass'],hue=df['Survived'],col=df['Sex'],kind='count')

# %%
df.groupby(['Sex','Pclass'])['Survived'].mean()
# Out:
# Sex     Pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: Survived, dtype: float64
