# %%
import zipfile
path = zipfile.ZipFile("dataset.zip")
path.extractall()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
train_data = tf.keras.utils.image_dataset_from_directory(
   "training_set",
    image_size = (128, 128),
    batch_size=32,
    subset = "training",
    validation_split = 0.2,
    seed = 42

)
# Out:
# Found 8005 files belonging to 1 classes.
# Using 6404 files for training.

# %%
test_data = tf.keras.utils.image_dataset_from_directory(
    "test_set",
    image_size = (128, 128),
    batch_size=32,
    subset = "validation",
    validation_split = 0.2,
    seed = 42

)
# Out:
# Found 2023 files belonging to 1 classes.
# Using 404 files for validation.

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# %%
cv2.imread("test_set/test_set/cats/cat.4004.jpg")
# Out:
# array([[[ 65,  86, 117],
#         [ 70,  91, 122],
#         [ 76,  97, 128],
#         ...,
#         [ 87,  88, 116],
#         [ 88,  87, 113],
#         [ 86,  85, 111]],
#
#        [[ 55,  76, 107],
#         [ 57,  78, 109],
#         [ 61,  82, 113],
#         ...,
#         [ 84,  87, 115],
#         [ 85,  86, 112],
#         [ 86,  85, 111]],
#
#        [[ 56,  77, 109],
#         [ 54,  75, 107],
#         [ 54,  75, 107],
#         ...,
#         [ 84,  87, 115],
#         [ 84,  88, 113],
#         [ 86,  87, 113]],
#
#        ...,
#
#        [[ 37,  48,  70],
#         [ 40,  51,  73],
#         [ 46,  53,  78],
#         ...,
#         [ 95, 126, 159],
#         [ 94, 125, 158],
#         [ 92, 123, 156]],
#
#        [[ 35,  46,  68],
#         [ 39,  50,  72],
#         [ 45,  52,  77],
#         ...,
#         [ 87, 118, 151],
#         [ 86, 117, 150],
#         [ 86, 117, 150]],
#
#        [[ 34,  45,  67],
#         [ 38,  49,  71],
#         [ 44,  51,  76],
#         ...,
#         [ 86, 117, 150],
#         [ 86, 117, 150],
#         [ 88, 119, 152]]], dtype=uint8)

# %%
Image.open("test_set/test_set/cats/cat.4010.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x412>
