# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Pivot Tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': [
        'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South'
    ],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': [
        'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice'
    ]
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)

# %%
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    927     32   John  January      Q1
# 1  2023-01-02       B   West    545     77   Mary  January      Q1
# 2  2023-01-03       C  North    260     46    Bob  January      Q1
# 3  2023-01-04       D  South    101     33  Alice  January      Q1
# 4  2023-01-05       A   East    501     87   John  January      Q1
# 5  2023-01-06       B   West    380     12   Mary  January      Q1
# 6  2023-01-07       C  North    906     35    Bob  January      Q1
# 7  2023-01-08       D  South    907     16  Alice  January      Q1
# 8  2023-01-09       A   East    979     80   John  January      Q1
# 9  2023-01-10       B   West    946     20   Mary  January      Q1
# 10 2023-01-11       C  North    431     56    Bob  January      Q1
# 11 2023-01-12       D  South    221     54  Alice  January      Q1
# 12 2023-01-13       A   East    811     16   John  January      Q1
# 13 2023-01-14       B   West    997     62   Mary  January      Q1
# 14 2023-01-15       C  North    359     59    Bob  January      Q1
# 15 2023-01-16       D  South    925     65  Alice  January      Q1
# 16 2023-01-17       A   East    567     92   John  January      Q1
# 17 2023-01-18       B   West    476     98   Mary  January      Q1
# 18 2023-01-19       C  North    859     60    Bob  January      Q1
# 19 2023-01-20       D  South    464     23  Alice  January      Q1

# %%
pd.pivot_table(df,values="Sales",index="Region",columns="Product",aggfunc="sum") # we can configure the agg function by own by default the agg function is mean
# Out:
# Product       A       B       C       D
# Region
# East     3785.0     NaN     NaN     NaN
# North       NaN     NaN  2815.0     NaN
# South       NaN     NaN     NaN  2618.0
# West        NaN  3344.0     NaN     NaN

# %%
pd.pivot_table(df,values=["Sales","Units"],index="Region",columns="Product")
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     757.0    NaN    NaN    NaN  61.4   NaN   NaN   NaN
# North      NaN    NaN  563.0    NaN   NaN   NaN  51.2   NaN
# South      NaN    NaN    NaN  523.6   NaN   NaN   NaN  38.2
# West       NaN  668.8    NaN    NaN   NaN  53.8   NaN   NaN

# %% [markdown]
# ### Cross Tab
#     It returns the count

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
