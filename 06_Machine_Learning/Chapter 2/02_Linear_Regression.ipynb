# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
#     Salary is an output variable because we are going to predict it based on ages. Usually in Linear Regression we plot a scatter plot in this plot we have 2 axis x and y axis. On x we will plot our input variable and on y we will plot our output variables. If we have a single input variable we will plot on x axis and on y we will plot what we have to predict. The circle is point where we see common thing like 22 and 36k.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     In the above image we can see there is a line passing between the scatter points this line is called as best fit line we can predict anything using this line in the above image we can see it is attempting to predict the salary of a person having age 29. I hope u got my point

# %% [markdown]
#     Lets see how we can create this best fit line because i can not randomly create the best fit line.To predict that line we have a formula which is as follows:
# ![image.png](attachment:image.png)
#
# ## **SLOPE**:
#     The slope is the measure of steepness and direction of line. It tells us how much the output changes for every single unit increase in input. For example if we have a slope of 1 it means for every 1 step forward on x-axis we will move 1 step up on y-axis.
#
#     By changing the slope value we tilt the line on our graph which helps the model to find the best fit for our data.

# %% [markdown]
# ## **INTERCEPT**:
#
#     Intercept is the point from where we start the y-axis like in the above image we can see our intercept point clearly is 0.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     In the above example we took slope as 1 and intercept as 0 by using these value we need to draw a graph and create the best fit line for our graph its as simple as this in the notebook properly solved example is present u can see in that too.

# %% [markdown]
#     The value of slope tell us how much steps we have to move in y-axis while for x-axis it depends on us like how many points we have to move its for our convinence.

# %% [markdown]
# ![image.png](attachment:image.png)
#
#     We can also write the formula in this way.

# %% [markdown]
# ## **RESIDUAL ERROR**
#     Its the difference between the actual data and the data that is predicted.
# ![image.png](attachment:image.png)
#
#     We will create multiple lines by tweaking the value of theta 0 and theta x and we will check the residual error properly for each line and we will consider that line which has the least difference between the actual data and the predicted one that line would be selected as best fit line. For this we will be using mean squared error and gradient decent.

# %% [markdown]
# ## **COST FUNCTION**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     Cost function is basically the sum of residual error where h theta is the predicted data and y is the actual data the formula is as follows:
# ![image-2.png](attachment:image-2.png)
#
#     Proper breakdown is in notes

# %% [markdown]
#     There are multiple cost function for every line because we manipulate the values of theta 0 and theta 1 to determine the best fit line. Inshort every line will have a different cost function.

# %% [markdown]
#     Our goal is to minimize the cost function by changing the value of theta 0 and theta 1.
#
# **Cost Function simply is an average of your residual error**

# %% [markdown]
#     Now a question comes how do we find the minimum cost function of a particular theta 0 or theta 1 for that we have Gradient Decent.

# %% [markdown]
# ### **Steps Are Simple Which Are As Follows:**
#     1. Define theta 0 and theta 1 values.
#     2. After that we will create a simple line.
#     3. After that we will provide values of those in our cost function.
#     4. Then that cost function will provide us a value.
#     5. Then we have to put that value in Gradient Decent.
#     6. Then we will find out the point where our cost function would be the minimum. Where we can create our best fit line.

# %% [markdown]
# ## **GRADIENT DECENT**

# %% [markdown]
#     We use Gradient Decent to find out the point where the cost function is minimum.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
