# %% [markdown]
# # **Performance Metrics**

# %% [markdown]
#     To see perfomance of out model we usually see two things
# **R Square** And **Adjusted R Square**
#
# **R Square** is to check how good our model is
#
#     The formula for R Square is as follows:
# ![image.png](attachment:image.png)
#
# **Residual** is the diff between actual data and the predicted data i.e the best fit line
#
# **Mean** is the difference between the data point and the line drawn from the mean of y-axis
#
#
# **Result will always be positive and in decimals**
#
#
# **To understand what basically Adjusted R square is look at an example**
#
#     For suppose you are predicting someone's salary using there age but the model accuracy is very low like 79% u added a feature for suppose that feature is location and now ur model's accuracy jumped to 88% becuase this feature was very co related to salary variable now to boost more accuracy u added an irrelevant feature like sleep ur model accuracy jumped to 90% but the scene is now that u deploy it in real life and its causing issues to fix this we use adjusted r square.
#
# **Formula for Adjusted R Square is as follows:**
# ![image-2.png](attachment:image-2.png)
#
# **Now lets see what it basically does**
#     Continuing our previous example what basically it does is we will continue from location thing its like we added location and our accuracy jumped to 88% as it was co-related and our adjusted r2 value too becomes 89% we see that its good but as soon as we added sleep feature the r2 value went to 89%  but our adjusted r2 value drop to 86% we now can see that this can cause issues in our future so we might look for alternatives.
#
# ![image-3.png](attachment:image-3.png)
