# %%
import numpy as np

# %% [markdown]
# **Valid Sudoku**

# %%
s = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],
    
    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],
    
    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
])

# %%
# we have to validate is it a valid sudoku or not
# for taking out sum of every row we will be using numpy addition
# for rows axis is 1 while for column is 0
sum_row = np.sum(s,axis = 1)
sum_row
# Out:
# array([45, 45, 45, 45, 45, 45, 45, 45, 45])

# %%
sum_column = np.sum(s,axis = 0)
sum_column
# Out:
# array([45, 45, 45, 45, 45, 45, 45, 45, 45])

# %%
# lets verify it too
b = np.sum(s,axis=1)
for i in b:
    if i != 45:        
        print("Sudoku Not Valid")
        break
else:
    print(f"For row it is valid")
# Out:
# For row it is valid

# %%
c = np.sum(s,axis = 0)
for i in b:
    if i != 45:
        print("Sudoku not valid")
        break
else:
    print("Not valid")
# Out:
# Not valid

# %%
block1 = s[0:3,0:3]
block1
block2 = s[0:3,3:6]
block2
block3 = s[0:3,6:9]
block3
# Out:
# array([[9, 1, 2],
#        [3, 4, 8],
#        [5, 6, 7]])

# %%
for i in range(0,9,3):
    for j in range(0,9,3):
        n = s[i:i+3,j:j+3]
        print(n.sum())
# Out:
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45

# %% [markdown]
# **General Questions**

# %%
import numpy as np

# Columns: [Age, Math Marks, Science Marks]
data = np.array([
    [18, 85, 78],   # Student 1
    [19, 92, 88],   # Student 2
    [17, 76, 95],   # Student 3
    [18, 65, 70],   # Student 4
    [20, 90, 85]    # Student 5
])

# %%
#Get the shape of the matrix.
data.shape
# 5 rows and 3 columns
# Out:
# (5, 3)

# %%
#Find the average age of students.
age = data[0:,0:1]
age
avg_age = np.average(age)
avg_age
# Out:
# np.float64(18.4)

# %%
#Extract Math marks of all students.
math = data[0:,1:2]
math
# Out:
# array([[85],
#        [92],
#        [76],
#        [65],
#        [90]])

# %%
#Find the highest Science mark.
science = data[0:,2:]
science
highest = np.max(science)
highest
# Out:
# np.int64(95)

# %%
#Get details of the student who scored more than 90 in Math.
detail = data[:,1] > 90
data[detail]
# Out:
# array([[19, 92, 88]])

# %%
#Increase Math marks of all students by 5.
math
increase = math + 5
increase
# Out:
# array([[90],
#        [97],
#        [81],
#        [70],
#        [95]])

# %%
#Find how many students are younger than 19.
age = data[0:,0:1]
age
younger = age < 19
age[younger]
len(age[younger])
# Out:
# 3

# %%
#Calculate the average marks in each subject (column-wise mean).
data[:,1:3]
np.mean(data[:,1:3],axis = 0)
# column wise thing is axis = 0
# Out:
# array([81.6, 83.2])

# %%
#Get data of students who scored at least 80 in both subjects.
score = data[(data[:,1] >= 80) & (data[:,2] >= 80)]
score
# Out:
# array([[19, 92, 88],
#        [20, 90, 85]])

# %%
#Replace all Science marks < 75 with 0.
data[0:,2][data[:,2] < 75] = 0
data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18, 65,  0],
#        [20, 90, 85]])
