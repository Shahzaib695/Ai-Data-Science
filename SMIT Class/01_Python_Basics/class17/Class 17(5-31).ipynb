# %% [markdown]
# ##
#     - Encapsulation
#     - inheritance
#     - polymorphisms
#
#
#
#     - abstraction

# %%
class parent:
    def __init__(self, name, age, roll):
        self.__name = name
        self.age = age
        self.roll = roll

    def getting(self):
        return self.__name
    def setting(self, new_name):
        self.__name = new_name

# %%
p1 =parent("ali","88","788")

# %%
p1.getting()
# Out:
# 'ali'

# %%
p1.setting("abdul")

# %%
p1.getting()
# Out:
# 'abdul'

# %%
p1.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 p1.name
#
# AttributeError: 'parent' object has no attribute 'name'

# %%
p1 =parent("ali","88","788")

# %%
p1.age= 77878888

# %%
p1.age
# Out:
# 77878888

# %%
p1.name = kio
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 p1.name = kio
#
# NameError: name 'kio' is not defined

# %%
class child(parent):
    def __init__(self, name, age,roll,  fee, gender, clas):
        super().__init__(name, age, roll)
        
        
        
        self.fee = fee
        self.gender = gender
        self.clas = clas
        
        
        
    def hello(self):
        print(f"{self.name}        chile class ka ")
    def paret_hello_class_call_kia(self):
        super().hello()

# %%
a1 = child("ali","88","788","900","male", "1")

# %%
a1.info()
# Out:
#            ali  88 788

# %%
a1.hello()
# Out:
# ali        chile class ka

# %%
a1.paret_hello_class_call_kia()
# Out:
# ali parent class ka
