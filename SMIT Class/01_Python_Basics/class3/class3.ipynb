# %%
a = 123;

# %%
a = 1234;
print(a);
# Out:
# 1234

# %%
b = "hello"
print(b)
# Out:
# hello

# %% [markdown]
# Operator Precedence
# -PEMDAS
# P = Parenthesis ()
# E = Exponent
# M = Multipication
# A = Addition
# S = Subtraction

# %%
12*90-18*(9+3)+90
# Out:
# 954

# %%
name = "Shahzaib";
name2 = name.upper();
print (name2);
# there are different functions for every type of data whether its string,int,bool,float
# Out:
# SHAHZAIB

# %%
course = "Ai And Data Science";
print (course);
c2 = course.upper();
print(c2)
# Out:
# Ai And Data Science
# AI AND DATA SCIENCE

# %%
# Strings are immutable
