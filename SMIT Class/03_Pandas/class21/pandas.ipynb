# %% [markdown]
# ### Pandas Class 3

# %%
import pandas as pd

# %%
data = pd.read_csv("movie.csv")

# %%
data.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1  No_of_Votes        Gross
# 0     Tim Robbins      2343110   28341469.0
# 1   Marlon Brando      1620367  134966411.0
# ...

# %%
data.tail()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  Meta_score          Director  \
# 995    Comedy, Drama, Romance          7.6        76.0     Blake Edwards
# 996            Drama, Western          7.6        84.0    George Stevens
# 997       Drama, Romance, War          7.6        85.0    Fred Zinnemann
# 998                Drama, War          7.6        78.0  Alfred Hitchcock
# 999  Crime, Mystery, Thriller          7.6        93.0  Alfred Hitchcock
#
#                  Star1  No_of_Votes       Gross
# 995     Audrey Hepburn       166544         NaN
# 996   Elizabeth Taylor        34075         NaN
# ...

# %% [markdown]
# ### Unique or Non Unique

# %%
data.Series_Title
# Out:
# 0      The Shawshank Redemption
# 1                 The Godfather
# 2               The Dark Knight
# 3        The Godfather: Part II
# 4                  12 Angry Men
#                  ...
# 995      Breakfast at Tiffany's
# 996                       Giant
# 997       From Here to Eternity
# 998                    Lifeboat
# 999                The 39 Steps
# Name: Series_Title, Length: 1000, dtype: str

# %%
data.Series_Title.unique()
# Out:
# <ArrowStringArray>
# [                     'The Shawshank Redemption',
#                                  'The Godfather',
#                                'The Dark Knight',
#                         'The Godfather: Part II',
#                                   '12 Angry Men',
#  'The Lord of the Rings: The Return of the King',
#                                   'Pulp Fiction',
#                               'Schindler's List',
#                                      'Inception',
#                                     'Fight Club',
#  ...
#                                   'Giù la testa',
#                                 'Kelly's Heroes',
#                                'The Jungle Book',
#                                         'Blowup',
#                             'A Hard Day's Night',
#                         'Breakfast at Tiffany's',
#                                          'Giant',
#                          'From Here to Eternity',
# ...

# %%
data.size
# Out:
# 11000

# %%
data.shape
# Out:
# (1000, 11)

# %%
data.Series_Title.nunique()
# Out:
# 999

# %%
data.Series_Title.value_counts()
# Out:
# Series_Title
# Drishyam                    2
# The Shawshank Redemption    1
# The Godfather               1
# The Dark Knight             1
# The Godfather: Part II      1
#                            ..
# Breakfast at Tiffany's      1
# Giant                       1
# From Here to Eternity       1
# Lifeboat                    1
# The 39 Steps                1
# Name: count, Length: 999, dtype: int64

# %%
data.Series_Title.isna().sum()
# Out:
# np.int64(0)

# %%
data.Released_Year.unique()
# Out:
# <ArrowStringArray>
# ['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010', '1999',
#  '2001', '1966', '2002', '1990', '1980', '1975', '2020', '2019', '2014',
#  '1998', '1997', '1995', '1991', '1977', '1962', '1954', '1946', '2011',
#  '2006', '2000', '1988', '1985', '1968', '1960', '1942', '1936', '1931',
#  '2018', '2017', '2016', '2012', '2009', '2007', '1984', '1981', '1979',
#  '1971', '1963', '1964', '1950', '1940', '2013', '2005', '2004', '1992',
#  '1987', '1986', '1983', '1976', '1973', '1965', '1959', '1958', '1952',
#  '1948', '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#  '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951', '1949',
#  '1939', '1937', '1934', '1928', '1926', '1920', '1970', '1969', '1956',
#  '1947', '1945', '1930', '1938', '1935', '1933', '1932', '1922', '1943',
#    'PG']
# Length: 100, dtype: str

# %%
data[data.Released_Year=="PG"]
# Out:
#     Series_Title Released_Year Certificate  Runtime  \
# 966    Apollo 13            PG           U  140 min
#
#                          Genre  IMDB_Rating  Meta_score    Director  \
# 966  Adventure, Drama, History          7.6        77.0  Ron Howard
#
#          Star1  No_of_Votes        Gross
# 966  Tom Hanks       269197  173837933.0

# %%
data[data.Released_Year == "PG"] = "1998"
data["Released_Year"] = data["Released_Year"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# LossySetitemError                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/internals/blocks.py:1115, in Block.setitem(self, indexer, value)
#    1114 try:
# -> 1115     casted = np_can_hold_element(values.dtype, value)
#    1116 except LossySetitemError:
#    1117     # current dtype cannot store value, coerce to common dtype
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/dtypes/cast.py:1792, in np_can_hold_element(dtype, element)
#    1790         return element
# -> 1792     raise LossySetitemError
#    1794 if dtype.kind == "c":
#
# LossySetitemError:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 data[data.Released_Year == "PG"] = "1998"
# ...

# %%
data.loc[966,"Released_Year"]
# Out:
# '1998'

# %%
data.Released_Year.unique()
# Out:
# <ArrowStringArray>
# ['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010', '1999',
#  '2001', '1966', '2002', '1990', '1980', '1975', '2020', '2019', '2014',
#  '1998', '1997', '1995', '1991', '1977', '1962', '1954', '1946', '2011',
#  '2006', '2000', '1988', '1985', '1968', '1960', '1942', '1936', '1931',
#  '2018', '2017', '2016', '2012', '2009', '2007', '1984', '1981', '1979',
#  '1971', '1963', '1964', '1950', '1940', '2013', '2005', '2004', '1992',
#  '1987', '1986', '1983', '1976', '1973', '1965', '1959', '1958', '1952',
#  '1948', '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#  '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951', '1949',
#  '1939', '1937', '1934', '1928', '1926', '1920', '1970', '1969', '1956',
#  '1947', '1945', '1930', '1938', '1935', '1933', '1932', '1922', '1943']
# Length: 99, dtype: str

# %%
data.Released_Year.dtype
# Out:
# dtype('int64')

# %%
data.loc[966]
# Out:
# Series_Title            1998
# Released_Year           1998
# Certificate             1998
# Runtime                 1998
# Genre                   1998
# IMDB_Rating              7.6
# Meta_score              77.0
# Director          Ron Howard
# Star1              Tom Hanks
# No_of_Votes           269197
# Gross            173837933.0
# Name: 966, dtype: object

# %%
data.Runtime = data.Runtime.str.replace(" ","")

# %%
data.loc[998]
# Out:
# Series_Title              Lifeboat
# Released_Year                 1944
# Certificate                    NaN
# Runtime                     97 min
# Genre                   Drama, War
# IMDB_Rating                    7.6
# Meta_score                    78.0
# Director          Alfred Hitchcock
# Star1            Tallulah Bankhead
# No_of_Votes                  26471
# Gross                          NaN
# Name: 998, dtype: object

# %%
data.Runtime.unique()
# Out:
# <ArrowStringArray>
# [ '142',  '175',  '152',  '202',   '96',  '201',  '154',  '195',  '148',
#   '139',
#  ...
#   '192',  '194',  '193',   '69',   '70',  '242',   '79',   '71', '1998',
#    '78']
# Length: 141, dtype: str

# %%
data.IMDB_Rating.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: IMDB_Rating, Length: 1000, dtype: bool

# %%
data.Gross.isna().sum()
# Out:
# np.int64(169)

# %%
data["Released_Year"] = data["Released_Year"].astype(int)
data[data.Released_Year >= 2000]
# Out:
#                                           Series_Title  Released_Year  \
# 2                                      The Dark Knight           2008
# 5        The Lord of the Rings: The Return of the King           2003
# 8                                            Inception           2010
# 10   The Lord of the Rings: The Fellowship of the Ring           2001
# 13               The Lord of the Rings: The Two Towers           2002
# ..                                                 ...            ...
# 948                                         The Others           2001
# 949                                               Blow           2001
# 950                                 Enemy at the Gates           2001
# 951                                    Minority Report           2002
# 953                                    American Psycho           2000
#
#     Certificate  Runtime                      Genre  IMDB_Rating  Meta_score  \
# ...

# %%
data[data.IMDB_Rating >= 9]
# Out:
#                Series_Title  Released_Year Certificate Runtime  \
# 0  The Shawshank Redemption           1994           A     142
# 1             The Godfather           1972           A     175
# 2           The Dark Knight           2008          UA     152
# 3    The Godfather: Part II           1974           A     202
# 4              12 Angry Men           1957           U      96
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1  No_of_Votes        Gross
# 0     Tim Robbins      2343110   28341469.0
# 1   Marlon Brando      1620367  134966411.0
# ...

# %%
# to find movies directed by christopher nolan
data[data.Director == "Christopher Nolan"]
# Out:
#               Series_Title  Released_Year Certificate  Runtime  \
# 2          The Dark Knight           2008          UA  152 min
# 8                Inception           2010          UA  148 min
# 21            Interstellar           2014          UA  169 min
# 36            The Prestige           2006           U  130 min
# 63   The Dark Knight Rises           2012          UA  164 min
# 69                 Memento           2000          UA  113 min
# 155          Batman Begins           2005          UA  140 min
# 573                Dunkirk           2017          UA  106 min
#
#                          Genre  IMDB_Rating  Meta_score           Director  \
# 2         Action, Crime, Drama          9.0        84.0  Christopher Nolan
# 8    Action, Adventure, Sci-Fi          8.8        74.0  Christopher Nolan
# 21    Adventure, Drama, Sci-Fi          8.6        74.0  Christopher Nolan
# 36      Drama, Mystery, Sci-Fi          8.5        66.0  Christopher Nolan
# ...

# %%
# to find which genre has what type of data
data.Genre.value_counts()
# Out:
# Genre
# Drama                        85
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Action, Crime, Mystery        1
# 1998                          1
# Animation, Drama, Romance     1
# Drama, War, Western           1
# Adventure, Comedy, War        1
# Name: count, Length: 203, dtype: int64

# %%
# to find how many drama genre movies we have
count = data[data.Genre == "Drama"]
count
# Out:
#                         Series_Title  Released_Year Certificate  Runtime  \
# 0           The Shawshank Redemption           1994           A  142 min
# 9                         Fight Club           1999           A  139 min
# 17   One Flew Over the Cuckoo's Nest           1975           A  133 min
# 20                   Soorarai Pottru           2020           U  153 min
# 40                American History X           1998           R  119 min
# ..                               ...            ...         ...      ...
# 933             Synecdoche, New York           2008           R  124 min
# 934                  Mysterious Skin           2004           R  105 min
# 941                        25th Hour           2002           R  135 min
# 946                Y tu mamá también           2001           A  106 min
# 981                   On Golden Pond           1981          UA  109 min
#
#      Genre  IMDB_Rating  Meta_score         Director                   Star1  \
# ...

# %%
drama_movies = data[data["Genre"].str.contains("Drama", na=False)]
drama_movies
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A  142 min
# 1               The Godfather           1972           A  175 min
# 2             The Dark Knight           2008          UA  152 min
# 3      The Godfather: Part II           1974           A  202 min
# 4                12 Angry Men           1957           U   96 min
# ..                        ...            ...         ...      ...
# 993                    Blowup           1966           A  111 min
# 995    Breakfast at Tiffany's           1961           A  115 min
# 996                     Giant           1956           G  201 min
# 997     From Here to Eternity           1953      Passed  118 min
# 998                  Lifeboat           1944         NaN   97 min
#
#                         Genre  IMDB_Rating  Meta_score  \
# 0                       Drama          9.3        80.0
# 1                Crime, Drama          9.2       100.0
# ...

# %%
# sort by imdb rating in descending order
data.sort_values(by="IMDB_Rating",ascending=False)
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A  142 min
# 1               The Godfather           1972           A  175 min
# 2             The Dark Knight           2008          UA  152 min
# 3      The Godfather: Part II           1974           A  202 min
# 4                12 Angry Men           1957           U   96 min
# ..                        ...            ...         ...      ...
# 995    Breakfast at Tiffany's           1961           A  115 min
# 996                     Giant           1956           G  201 min
# 997     From Here to Eternity           1953      Passed  118 min
# 998                  Lifeboat           1944         NaN   97 min
# 999              The 39 Steps           1935         NaN   86 min
#
#                         Genre  IMDB_Rating  Meta_score              Director  \
# 0                       Drama          9.3        80.0        Frank Darabont
# ...

# %%
data[data.Runtime.max()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...

# %%
data[data.Star1 .str.contains("Leonardo")]
# Out:
#                          Series_Title  Released_Year Certificate  Runtime  \
# 8                           Inception           2010          UA  148 min
# 37                       The Departed           2006           A  151 min
# 145                    Shutter Island           2010           A  138 min
# 147           The Wolf of Wall Street           2013           A  180 min
# 243               Catch Me If You Can           2002           A  141 min
# 343                      The Revenant           2015           A  156 min
# 361                     Blood Diamond           2006           A  143 min
# 652                           Titanic           1997          UA  194 min
# 879  Once Upon a Time... in Hollywood           2019           A  161 min
#
#                           Genre  IMDB_Rating  Meta_score  \
# 8     Action, Adventure, Sci-Fi          8.8        74.0
# 37       Crime, Drama, Thriller          8.5        85.0
# ...

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[150], line 2
#       1 import numpy as np
# ----> 2 ist = np.array(ist)
#
# NameError: name 'ist' is not defined

# %%
# movies released between 2010 and 2014
data[(data.Released_Year >= 2010) & (data.Released_Year <= 2014)]
# Out:
#            Series_Title  Released_Year Certificate  Runtime  \
# 8             Inception           2010          UA  148 min
# 21         Interstellar           2014          UA  169 min
# 34             Whiplash           2014           A  106 min
# 35     The Intouchables           2011          UA  112 min
# 62     Django Unchained           2012           A  165 min
# ..                  ...            ...         ...      ...
# 906       Despicable Me           2010           U   95 min
# 907               50/50           2011           R  100 min
# 908            Kick-Ass           2010          UA  117 min
# 910           Moneyball           2011       PG-13  133 min
# 911  La piel que habito           2011           R  120 min
#
#                          Genre  IMDB_Rating  Meta_score           Director  \
# 8    Action, Adventure, Sci-Fi          8.8        74.0  Christopher Nolan
# 21    Adventure, Drama, Sci-Fi          8.6        74.0  Christopher Nolan
# ...

# %%
import numpy as np
data["Random_Number"] = np.random.randint(1,1001,size=len(data))

# %%
data
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A  142 min
# 1               The Godfather           1972           A  175 min
# 2             The Dark Knight           2008          UA  152 min
# 3      The Godfather: Part II           1974           A  202 min
# 4                12 Angry Men           1957           U   96 min
# ..                        ...            ...         ...      ...
# 995    Breakfast at Tiffany's           1961           A  115 min
# 996                     Giant           1956           G  201 min
# 997     From Here to Eternity           1953      Passed  118 min
# 998                  Lifeboat           1944         NaN   97 min
# 999              The 39 Steps           1935         NaN   86 min
#
#                         Genre  IMDB_Rating  Meta_score              Director  \
# 0                       Drama          9.3        80.0        Frank Darabont
# ...
