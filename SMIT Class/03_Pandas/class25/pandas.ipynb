# %% [markdown]
# ### Pandas:
#         Stats
#         Query
#         Clean
#         Eda
#         Transformation
#         Datasets concat and merging
#         Graphs
#         Time series

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = sns.load_dataset('titanic')
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 100.4 KB

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='str')

# %%
data.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data.shape
# Out:
# (891, 15)

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.duplicated().sum()
# Out:
# np.int64(107)

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.rename(columns={"sex":"Gender"},inplace=True)

# %%
data
# Out:
#      survived  pclass  Gender   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.drop(['sibsp','parch','embarked','who','adult_male','deck','alone'],axis=1,inplace=True)

# %%
data
# Out:
#      survived  pclass  Gender   age     fare  class  embark_town alive
# 0           0       3    male  22.0   7.2500  Third  Southampton    no
# 1           1       1  female  38.0  71.2833  First    Cherbourg   yes
# 2           1       3  female  26.0   7.9250  Third  Southampton   yes
# 3           1       1  female  35.0  53.1000  First  Southampton   yes
# 4           0       3    male  35.0   8.0500  Third  Southampton    no
# ..        ...     ...     ...   ...      ...    ...          ...   ...
# 885         0       3  female  39.0  29.1250  Third   Queenstown    no
# 887         1       1  female  19.0  30.0000  First  Southampton   yes
# 888         0       3  female   NaN  23.4500  Third  Southampton    no
# 889         1       1    male  26.0  30.0000  First    Cherbourg   yes
# 890         0       3    male  32.0   7.7500  Third   Queenstown    no
#
# [784 rows x 8 columns]

# %%
data.drop(['pclass'],axis=1,inplace=True)

# %%
data
# Out:
#      survived  Gender   age     fare  class  embark_town alive
# 0           0    male  22.0   7.2500  Third  Southampton    no
# 1           1  female  38.0  71.2833  First    Cherbourg   yes
# 2           1  female  26.0   7.9250  Third  Southampton   yes
# 3           1  female  35.0  53.1000  First  Southampton   yes
# 4           0    male  35.0   8.0500  Third  Southampton    no
# ..        ...     ...   ...      ...    ...          ...   ...
# 885         0  female  39.0  29.1250  Third   Queenstown    no
# 887         1  female  19.0  30.0000  First  Southampton   yes
# 888         0  female   NaN  23.4500  Third  Southampton    no
# 889         1    male  26.0  30.0000  First    Cherbourg   yes
# 890         0    male  32.0   7.7500  Third   Queenstown    no
#
# [784 rows x 7 columns]

# %%
data['Gender'].value_counts()
# Out:
# Gender
# male      491
# female    293
# Name: count, dtype: int64

# %%
x = data.Gender.value_counts().index
x
# Out:
# Index(['male', 'female'], dtype='str', name='Gender')

# %%
y = data.Gender.value_counts().values
y
# Out:
# array([491, 293])

# %%
sns.barplot(x=x,y=y,palette=['g','r'])#type = ignore
# Out:
# /tmp/ipykernel_9780/160346847.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x,y=y,palette=['g','r'])#type = ignore
# <Axes: xlabel='Gender'>

# %%
data.Gender.value_counts().plot(kind='bar') 
#shortcut
# Out:
# <Axes: xlabel='Gender'>

# %%
sns.histplot(data.age,kde=True) # type: ignore
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
data['class'].value_counts()
# Out:
# class
# Third     405
# First     214
# Second    165
# Name: count, dtype: int64

# %%
plt.title("Class Counts")
sns.countplot(x=data['class'], palette='rainbow')
plt.xlabel('Class Name')
plt.ylabel('Count Of Class')
# Out:
# /tmp/ipykernel_9780/1025415897.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['class'], palette='rainbow')
# Text(0, 0.5, 'Count Of Class')

# %%
x=data['embark_town'].value_counts()
y=data['embark_town'].value_counts().index

# %%
plt.title("Pie Chart Of Embark Town",fontdict={
    "size":16,
    "color" : "Green"
    })
plt.pie(x=x,autopct="%.2f%%",labels=y,colors=['b','g','r'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7b6246b9afd0>,
# ...
#  [Text(-0.7179148808490451, 0.8334255958725421, 'Southampton'),
#   Text(0.5021437432169686, -0.9786989634959522, 'Cherbourg'),
#   Text(1.069244779319076, -0.25829363503365854, 'Queenstown')],
#  [Text(-0.39158993500857, 0.45459577956684105, '72.63%'),
#   Text(0.2738965872092556, -0.5338357982705193, '19.82%'),
#   Text(0.5832244250831323, -0.14088743729108646, '7.54%')])

# %%
sns.boxplot(data['age'])
# Out:
# <Axes: ylabel='age'>

# %%
data.age.value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='age'>

# %%
data['fare'].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='fare'>

# %%
data.embark_town.value_counts().plot(kind="area")
# Out:
# <Axes: xlabel='embark_town'>
