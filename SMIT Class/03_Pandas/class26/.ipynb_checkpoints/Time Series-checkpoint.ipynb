# %% [markdown]
# ## Time Series

# %% [markdown]
# # Time Series Analysis and Forecasting
#     Last Updated : 19 Dec, 2025
#     To understand how data changes over time, Time Series Analysis and Forecasting are used, which help track past patterns and predict future values. It is widely used in finance, weather, sales and sensor data.
#
#     Focuses on data collected at regular time intervals
#     Helps identify trends, seasonality and sudden changes
#     Useful for planning, prediction and decision-making
#     Common methods include ARIMA, exponential smoothing and machine learning models

# %% [markdown]
# ![image.png](attachment:dc0a178d-b46f-4340-af19-d2dbcbba87d6.png)

# %%
# !pip install datetime

# %%
from datetime import datetime

# %%
date_now=datetime.now()
date_now
# Out:
# datetime.datetime(2026, 7, 10, 21, 38, 36, 52462)

# %%
date_now.year
# Out:
# 2026

# %%
date_now.month
# Out:
# 7

# %%
date_now.time()
# Out:
# datetime.time(21, 38, 36, 52462)

# %%
date_now.day
# Out:
# 10

# %%
date_now.microsecond
# Out:
# 52462

# %% [markdown]
# ## converting string betweemn datetime
#      --- strftime   (datetime to string)
#      --- strptime    ( string to datetime)

# %% [markdown]
# # datetime to string

# %%
string_datetime = date_now.strftime("%B-%A-%Y")

# %%
date_now.strftime("%Y-%A-%C")
# Out:
# '2026-Friday-20'

# %% [markdown]
# # string to datetime

# %%
date_now.strptime("2026-6-8", "%Y-%m-%d")
# Out:
# datetime.datetime(2026, 6, 8, 0, 0)

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Using cached yfinance-1.5.1-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pandas>=1.3.0 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from yfinance) (3.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: requests>=2.31 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from yfinance) (2.34.2)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.13-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from yfinance) (4.9.4)
# Requirement already satisfied: pytz>=2022.5 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from yfinance) (2026.2)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-4.1.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from yfinance) (4.14.3)
# Collecting curl_cffi>=0.15 (from yfinance)
#   Using cached curl_cffi-0.15.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: protobuf>=3.19.0 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from yfinance) (6.33.5)
# Requirement already satisfied: websockets>=13.0 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from curl_cffi>=0.15->yfinance) (2026.5.20)
# Requirement already satisfied: rich in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from curl_cffi>=0.15->yfinance) (15.0.0)
# Requirement already satisfied: pycparser in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from rich->curl_cffi>=0.15->yfinance) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from rich->curl_cffi>=0.15->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.2)
# Using cached yfinance-1.5.1-py2.py3-none-any.whl (144 kB)
# Downloading curl_cffi-0.15.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 500.7 kB/s  0:00:22m0:00:0100:01
# Downloading multitasking-0.0.13-py3-none-any.whl (16 kB)
# Downloading peewee-4.1.2-py3-none-any.whl (173 kB)
# Installing collected packages: peewee, multitasking, curl_cffi, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [yfinance]3/4 [yfinance]]
# Successfully installed curl_cffi-0.15.0 multitasking-0.0.13 peewee-4.1.2 yfinance-1.5.1

# %%
# %pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.11.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: lxml in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from pandas_datareader) (6.1.0)
# Requirement already satisfied: pandas>=2.1.4 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from pandas_datareader) (3.0.3)
# Requirement already satisfied: requests>=2.19.0 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from pandas_datareader) (2.34.2)
# Requirement already satisfied: setuptools in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from pandas_datareader) (82.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from pandas>=2.1.4->pandas_datareader) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from pandas>=2.1.4->pandas_datareader) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.1.4->pandas_datareader) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from requests>=2.19.0->pandas_datareader) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from requests>=2.19.0->pandas_datareader) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from requests>=2.19.0->pandas_datareader) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/shahzaib/anaconda3/lib/python3.13/site-packages (from requests>=2.19.0->pandas_datareader) (2026.5.20)
# Downloading pandas_datareader-0.11.1-py3-none-any.whl (65 kB)
# Installing collected packages: pandas_datareader
# Successfully installed pandas_datareader-0.11.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
from pandas_datareader import data as pdr

# %%
start = "2023-1-1"
end = datetime.now()

# %%
data = pdr.DataReader(['sp500'], "fred", start=start, end = end)

# %%
data.head()
# Out:
#               sp500
# DATE
# 2023-01-02      NaN
# 2023-01-03  3824.14
# 2023-01-04  3852.97
# 2023-01-05  3808.10
# 2023-01-06  3895.08

# %%
data.tail()
# Out:
#               sp500
# DATE
# 2026-07-03      NaN
# 2026-07-06  7537.43
# 2026-07-07  7503.85
# 2026-07-08  7482.71
# 2026-07-09  7543.64

# %%
data["2023-01-06":"2026-06-26"]
# Out:
#               sp500
# DATE
# 2023-01-06  3895.08
# 2023-01-09  3892.09
# 2023-01-10  3919.25
# 2023-01-11  3969.61
# 2023-01-12  3983.17
# ...             ...
# 2026-06-22  7472.79
# 2026-06-23  7365.46
# 2026-06-24  7358.22
# 2026-06-25  7357.49
# 2026-06-26  7354.02
#
# [906 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(22,10))
plt.plot(data["sp500"])
plt.title("Trend of Sp500 data", fontdict={"size":20, "color":"r"})
plt.xlabel("Date",fontdict={"size":20, "color":"r"})
plt.ylabel("Amounts in Dollar",fontdict={"size":20, "color":"r"})
plt.show()

# %% [markdown]
# # Using yfinace library
#
# googl, tsla, aapl, amz   (open)

# %%
yf.download("AAPL")

# %%
stock_list=["TSLA","AAPL","AMZN","GOOGL"]
year = 3

# %%
import pandas as pd

# %%
stock_df_price=pd.DataFrame()
for stock in stock_list:
    data = yf.download(stock, period=f'{year}y')
    stock_df_price[stock] = data["Open"]
stock_df_price.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                   TSLA        AAPL        AMZN       GOOGL
# Date
# 2023-07-03  276.489990  191.100906  130.820007  118.191966
# 2023-07-05  278.820007  188.921502  130.240005  118.191968
# 2023-07-06  278.089996  187.215377  128.250000  118.747041
# 2023-07-07  278.429993  188.763680  128.589996  119.044409
# 2023-07-10  276.470001  186.643403  129.070007  117.260237

# %%
plt.figure(figsize=(22,10), facecolor="y",edgecolor="r",)
plt.title("OPen pricing",fontdict={"size":20, "color":"r"})
plt.plot(stock_df_price["TSLA"],label = "Tsla")
plt.plot(stock_df_price["AAPL"], label = "AApl")
plt.plot(stock_df_price["AMZN"], label="AMZN")
plt.plot(stock_df_price["GOOGL"], label = "GOOgle")
plt.xlabel("Date",fontdict={"size":20, "color":"r"})
plt.ylabel("Amounts in Dollar",fontdict={"size":20, "color":"r"})
plt.legend()
plt.grid(True)
plt.show()

# %%
# functions to plot interactive plotly charts
import plotly.express as px
def interactive_plot(df):
    fig = px.line()
    for i in df.columns:
        fig.add_scatter(x=df.index, y=df[i], name=i)
    fig.update_layout(
         title='Open Pricing ',
         xaxis_title='Date',
         yaxis_title='Amounts',
        width=890,
        margin=dict(l=20, r=20, t=50, b=20),
        legend=dict(
                    orientation="h",
                    yanchor="bottom",
                    y=1.02,
                    xanchor="right",
                    x=1))

    return fig

# %%
interactive_plot(stock_df_price)
